# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100) #The numpy.linspace() function returns number spaces evenly w.r.t interval

y = np.sin(x)

plt.plot(x, y, linestyle='dashed')
plt.show()
