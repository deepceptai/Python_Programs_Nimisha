# %% [markdown]
# Write a Python code snippet to plot a stacked area chart.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.1)

y1 = np.sin(x)

y2 = np.cos(x)

plt.stackplot(x, y1, y2, labels=['sin(x)', 'cos(x)'])

plt.legend(loc='upper left')

plt.show()
