# %%
import matplotlib.pyplot as plt

import numpy as np

data = np.random.normal(size=1000)

plt.hist(data, bins=30) #histogram displays continuous data as bars that represent the frequency of data points in a given range

plt.show()
